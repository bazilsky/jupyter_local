# %%
import numpy as np 
import pandas as pd 
from pylab import plt,mpl
plt.style.use('seaborn')
mpl.rcParams['savefig.dpi'] = 300
pd.set_option('precision', 4) 
np.set_printoptions(suppress=True, precision=4)
url = 'http://hilpisch.com/aiif_eikon_eod_data.csv'
data = pd.read_csv(url,index_col = 0,parse_dates = True).dropna()
for ric in data:
    print(ric)
# Out:
# AAPL.O
# MSFT.O
# INTC.O
# AMZN.O
# GS.N
# SPY
# .SPX
# .VIX
# EUR=
# XAU=
# GDX
# GLD

# %%
#using indicators like SMA and momentum as features to train neural networks

def add_lags(data,ric,lags,window = 50):
    cols = []
    df = pd.DataFrame(data[ric])
    df.dropna(inplace = True)
    df['r'] = np.log(df/df.shift())
    df['sma'] = df[ric].rolling(window).mean()
    df['min'] = df[ric].rolling(window).min()
    df['max'] = df[ric].rolling(window).max()
    df['mom'] = df['r'].rolling(window).mean()
    df['vol'] = df['r'].rolling(window).std()
    df.dropna(inplace = True)
    df['d'] = np.where(df['r']>0,1,0)
    features = [ric,'r','d','sma','min','max','mom','vol']
    for f in features:
        for lag in range(1,lags+1):
            col = f'{f}_lag_{lag}'
            df[col] = df[f].shift(lag)
            cols.append(col)
    df.dropna(inplace = True)
    return df,cols

# %%
lags = 5
dfs = {}
for ric in data:
    df,cols = add_lags(data,ric,lags)
    dfs[ric] = df.dropna(), cols

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
# %%time
for ric in data:
    model = MLPClassifier(hidden_layer_sizes = [512],
                          random_state = 100,
                          max_iter = 100,
                         early_stopping = True,
                         validation_fraction = 0.15,
                         shuffle = False)
    df,cols = dfs[ric]
    df[cols] = (df[cols] - df[cols].mean())/df[cols].std()
    model.fit(df[cols],df['d'])
    pred = model.predict(df[cols])
    acc = accuracy_score(df['d'], pred)
    print(f'IN-SAMPLE | {ric:7s} | acc = {acc:.4f}')
# Out:
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | AAPL.O  | acc = 0.5510
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | MSFT.O  | acc = 0.5376
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | INTC.O  | acc = 0.5607
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | AMZN.O  | acc = 0.5559
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | GS.N    | acc = 0.5794
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | SPY     | acc = 0.5729
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | .SPX    | acc = 0.5941
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | .VIX    | acc = 0.6940
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | EUR=    | acc = 0.5766
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | XAU=    | acc = 0.5672
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# IN-SAMPLE | GDX     | acc = 0.5847
# IN-SAMPLE | GLD     | acc = 0.5567
# CPU times: user 30.6 s, sys: 6.34 s, total: 37 s
# Wall time: 6.31 s
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
# a way to avoid overfitting, is to use ensemble methods to come up with a 
# more robust meta model and better out of sample predictions

# methods called bagging, bagging avoids 
#overfitting to some extent and improves predictions noticeably
from sklearn.ensemble import BaggingClassifier

# %%
def train_test_model(model):
    for ric in data:
        
        df,cols = dfs[ric]
        split = int(len(df)*0.85)
        train = df.iloc[:split].copy()
        mu, std = train[cols].mean(), train[cols].std()
        train[cols] = (train[cols] - mu)/std
        model.fit(train[cols],train['d'])
        test = df.iloc[split:].copy()
        test[cols] = (test[cols] - mu)/std
        pred = model.predict(test[cols])
        acc = accuracy_score(test['d'], pred)
        
base_estimator = MLPClassifier(hidden_layer_sizes = [256], 
                              random_state = 100,
                              max_iter = 1000,
                              early_stopping = True,
                              validation_fraction = 0.15,
                              shuffle = False)

# %%
model_bag = BaggingClassifier(base_estimator = base_estimator, 
                             n_estimators = 35, 
                             max_samples = 0.25,
                             max_features = 0.5,
                             bootstrap = False, 
                             bootstrap_features = True,
                             n_jobs = 8,
                             random_state = 100)

# %%
# %time train_test_model(model_bag)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed eval> in <module>
#
# NameError: name 'train_test_model' is not defined
