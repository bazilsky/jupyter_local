# %%
from netCDF4 import Dataset
import iris
import numpy as np
import pylab as plt
import cartopy.crs as ccrs
import cartopy.feature
from datetime import datetime,timedelta
from dateutil.relativedelta import relativedelta

# %%
#filename = '/Users/ananth/Downloads/SM_sden_ERA5_01Aug1980-31Jul2021_v01.nc'
#cube = iris.load(filename)

filename = '/Users/ananth/Downloads/SM_snod_ERA5_01Aug1980-31Jul2021_v01.nc'
cube = iris.load(filename)

lat_index = 0
lon_index = 0
snowdepth_index = 0

for i in range(2):
    varname = cube[i].var_name
    if varname == 'snod':
        snowdepth_index = i

snow_depth_org = cube[snowdepth_index].data
snow_depth_org[snow_depth_org<0] = 0
filename4 = '/Users/ananth/Downloads/icemotion_weekly_nh_25km_19781105_19781231_v4.1.nc'
cube4 = iris.load(filename4)

lat_index = 0
lon_index = 0

for i in range(5):
    varname = cube4[i].var_name
    if varname == 'latitude':
        lat_index = i
    elif varname == 'longitude':
        lon_index = i
        
lon = cube4[lon_index].data
lat = cube4[lat_index].data

snow_depth = snow_depth_org[-365:,:,:].data # this is for the one year .. slice 

snow_depth_1yr = snow_depth_org[-30:,:,:].data
# Out:
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/iris/fileformats/cf.py:649: UserWarning: Missing CF-netCDF grid mapping variable 'lambert_azimuthal_equal_area', referenced by netCDF variable 'snod'
#   warnings.warn(message % (name, nc_var_name))

# %%
depth_cube = cube[snowdepth_index]
time_arr = depth_cube.coord('time').points
np.shape(time_arr)

start_date = '08/01/1980'
date_1 = datetime.strptime(start_date,'%m/%d/%Y').date()
date_arr =[start_date]
#new_date = []
new_date = 0

for i in range(len(time_arr)-1):
    new_date = date_1+timedelta(days = i)
    new_date_str = new_date.strftime('%m/%d/%Y')
    date_arr += [new_date_str]
    #print(date_arr)

index_1 = date_arr.index('01/01/2020')
index_2 = date_arr.index('12/31/2020')
#date_arr[index_1:index_2+1]

snow_depth_1yr_slice = snow_depth_org[index_1:index_2+1,:,:].data

start_date_2 = datetime.strptime('01/01/2020','%m/%d/%Y').date()

snow_depth_annual = np.zeros((12,361,361))

for i in range(12):
    
    new_date_2 = start_date_2+relativedelta(months= i) 
    new_date_2_str = new_date_2.strftime('%m/%d/%Y')
    index_2 = date_arr.index(new_date_2_str)
    snow_depth_1month = snow_depth_org[index_1:index_2+1,:,:]
    snow_depth_1month_mean = np.mean(snow_depth_1month,axis=0)
    snow_depth_annual[i,:,:] = snow_depth_1month_mean.data
    
    print(index_1,index_2)
    index_1 = index_2
    print(date_arr[index_2])
    
print(np.shape(snow_depth_annual))
# Out:
# 14398 14398
# 01/01/2020
# 14398 14429
# 02/01/2020
# 14429 14458
# 03/01/2020
# 14458 14489
# 04/01/2020
# 14489 14519
# 05/01/2020
# 14519 14550
# 06/01/2020
# 14550 14580
# 07/01/2020
# 14580 14611
# 08/01/2020
# 14611 14642
# 09/01/2020
# 14642 14672
# 10/01/2020
# 14672 14703
# 11/01/2020
# 14703 14733
# 12/01/2020
# (12, 361, 361)

# %%
# convert snow_depth_annual from 12,361,361 array to 12,722,722

lat_org = np.sort(lat.flatten())
lon_org = np.sort(lon.flatten())


lat_1d = lat.flatten()
lon_1d = lon.flatten()

lat_sort_index = np.argsort(lat_1d)
lon_sort_index = np.argsort(lon_1d)



lat_lon = np.zeros((722,722))

new_SD = np.zeros((12,722,722))

for i in range(722):
    index1 = np.where(lat_sort_index == i)
    index2 = np.where(lon_sort_index == i)
    
    new_SD[0,index1,index2] = snow_depth_annual[0,] 
    


"""
for i in range(len(lat_org)):
    index1 = np.where(lat_1d[i]==lat_org)
    index2 = np.where(lon_1d[index_1] == lon_org)
    for j in range(len(index1)):
        new_SD[0,j,index2]
        
        for j in range(len(lon_org)):
            index3 = np.where(lon)
        

np.shape(snow_depth_annual)

"""

a = np.array([1,2,3,4,5,0])
b= np.array([12,1,14,3,7,0])
print(np.argsort(a))
print(np.argsort(b))

np.where(lat_sort_index==1)
lat_sort_index[4]
# Out:
# [5 0 1 2 3 4]
# [5 1 3 4 0 2]
# 1

# %%
# save snow depth, latitude and longitude into a netcdf file
import netCDF4 as nc
import os

fn = 'snow_depth_1.nc'

os.remove(fn)
ds = nc.Dataset(fn,'w',format = 'NETCDF4')

time = ds.createDimension('time',12)
lat_dim = ds.createDimension('unknown1',361)
lon_dim = ds.createDimension('unknown2',361)

temp_time = np.arange(1,13,1)
temp_lat = np.linspace(1,2,361)
temp_lon = np.linspace(1,2,361)
np.shape(temp_time)

times = ds.createVariable('time', 'f4', ('time',))
lats = ds.createVariable('unknown1', 'f4', ('unknown1',))
lons = ds.createVariable('unknown2', 'f4', ('unknown2',))
value = ds.createVariable('snow_depth', 'f4', ('time', 'unknown1', 'unknown2',))
value.units = 'm'

lats[:]=temp_lat
lons[:]=temp_lon
times[:]= temp_time

value[:,:,:] = snow_depth_annual
ds.close()

cube111 = iris.load('snow_depth_1.nc')
cube111
# Out:
# [<iris 'Cube' of snow_depth / (m) (time: 12; unknown1: 361; unknown2: 361)>]

# %%
#save latitude into a cube

import netCDF4 as nc
import os

fn = 'latitude.nc'

os.remove(fn)
ds = nc.Dataset(fn,'w',format = 'NETCDF4')

#time = ds.createDimension('time',12)
lat_dim = ds.createDimension('unknown1',361)
lon_dim = ds.createDimension('unknown2',361)

#temp_time = np.arange(1,13,1)
temp_lat = np.linspace(1,2,361)
temp_lon = np.linspace(1,2,361)
#np.shape(temp_time)

#times = ds.createVariable('time', 'f4', ('time',))
lats = ds.createVariable('unknown1', 'f4', ('unknown1',))
lons = ds.createVariable('unknown2', 'f4', ('unknown2',))
value = ds.createVariable('latitude', 'f4', ('unknown1', 'unknown2',))
value.units = 'm'

lats[:]=temp_lat
lons[:]=temp_lon
#times[:]= temp_time

value[:,:] = lat
ds.close()

cube111 = iris.load('latitude.nc')
cube111
# Out:
# [<iris 'Cube' of latitude / (m) (unknown1: 361; unknown2: 361)>]

# %%
#save longitude array into a cube

import netCDF4 as nc
import os

fn = 'longitude.nc'

#os.remove(fn)
ds = nc.Dataset(fn,'w',format = 'NETCDF4')

#time = ds.createDimension('time',12)
lat_dim = ds.createDimension('unknown1',361)
lon_dim = ds.createDimension('unknown2',361)

#temp_time = np.arange(1,13,1)
temp_lat = np.linspace(1,2,361)
temp_lon = np.linspace(1,2,361)
#np.shape(temp_time)

#times = ds.createVariable('time', 'f4', ('time',))
lats = ds.createVariable('unknown1', 'f4', ('unknown1',))
lons = ds.createVariable('unknown2', 'f4', ('unknown2',))
value = ds.createVariable('longitude', 'f4', ('unknown1', 'unknown2',))
value.units = 'm'

lats[:]=temp_lat
lons[:]=temp_lon
#times[:]= temp_time

value[:,:] = lon
ds.close()

cube111 = iris.load('longitude.nc')
cube111
# Out:
# [<iris 'Cube' of longitude / (m) (unknown1: 361; unknown2: 361)>]

# %%
snow_depth_1yr = snow_depth_org[-730:-365,:,:].data
snow_depth_1yr[snow_depth_1yr<0] = 0
snow_depth = np.mean(snow_depth_1yr,axis=0)
np.max(snow_depth)

#np.max(snow_depth_annual)
# Out:
# 0.43727094

# %%
fig, ax = plt.subplots(1,1,figsize=(8,8),  subplot_kw={'projection': ccrs.NorthPolarStereo()})

ax.add_feature(cartopy.feature.LAND, edgecolor='black',zorder=1)
#ax.add_feature(cartopy.feature.OCEAN)

lat_1d = lat.flatten();
lon_1d = lon.flatten();

snowdepth_1d = snow_depth.flatten()*100

#j = np.isnan(snowdepth_1d)
#s_depth_slice = snowdepth_1d[~j]
#lat_slice = lat_1d[~j]
#lon_slice = lon_1d[~j]

#colors = snowdepth_1d/np.max(snowdepth_1d_depth_slice)

colors = snowdepth_1d

im = ax.scatter(lon_1d, lat_1d,c = colors,s = 100, marker = '.',transform = ccrs.PlateCarree(),zorder = 5)
cb = fig.colorbar(im,ax=ax,fraction=0.046, pad=0.04)
ax.set_extent([-180, 180, 90, 60], ccrs.PlateCarree())
cb.ax.tick_params(labelsize=18)
plt.title('Snow depth (cm) (SnowModel LG data)',fontsize = 24)
ax.gridlines()

"""         
#ax.scatter(lat[])
#ax.colorbar()
ax.set_title('Snow depth in the Arctic (cm)',fontsize=25)
cb.ax.tick_params(labelsize=18)
#ax.legend(fontsize='x-large')
ax.gridlines()
"""
# Out:
# "         \n#ax.scatter(lat[])\n#ax.colorbar()\nax.set_title('Snow depth in the Arctic (cm)',fontsize=25)\ncb.ax.tick_params(labelsize=18)\n#ax.legend(fontsize='x-large')\nax.gridlines()\n"

# %%
np.shape(snow_depth)
# Out:
# (361, 361)

# %%
filename3 = '/Users/ananth/Downloads/SM_sden_MERRA2_01Aug1980-31Jul2021_v01.nc'
cube3 = iris.load(filename3)
# Out:
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/iris/fileformats/cf.py:649: UserWarning: Missing CF-netCDF grid mapping variable 'lambert_azimuthal_equal_area', referenced by netCDF variable 'sden'
#   warnings.warn(message % (name, nc_var_name))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/m6/qj3v2qcs35d7x8gdhqzsc7280000gn/T/ipykernel_40213/2266749134.py in <module>
#       1 filename3 = '/Users/ananth/Downloads/SM_sden_MERRA2_01Aug1980-31Jul2021_v01.nc'
#       2 cube3 = iris.load(filename3)
# ----> 3 np.shape(snow_depth_1d)
#
# NameError: name 'snow_depth_1d' is not defined

# %%
filename4 = '/Users/ananth/Downloads/icemotion_weekly_nh_25km_19781105_19781231_v4.1.nc'
cube4 = iris.load(filename4)
cube4
# Out:
# [<iris 'Cube' of latitude / (degrees) (-- : 361; -- : 361)>,
# <iris 'Cube' of longitude / (degrees) (-- : 361; -- : 361)>,
# <iris 'Cube' of number_of_observations / (1) (time: 52; -- : 361; -- : 361)>,
# <iris 'Cube' of sea_ice_x_velocity / (cm / s) (time: 52; projection_y_coordinate: 361; projection_x_coordinate: 361)>,
# <iris 'Cube' of sea_ice_y_velocity / (cm / s) (time: 52; projection_y_coordinate: 361; projection_x_coordinate: 361)>]

# %%
#start_date = '08-01-1980'
#date_1 = datetime.strptime(start_date,'%m-%d-%Y').date()

start_date = '08/01/1980'
date_1 = datetime.strptime(start_date,'%m/%d/%Y').date()
#x = datetime.datetime.strptime('08/01/1980','%m/%d/%y')

# %%
from datetime import datetime,timedelta

datetime_str = '09/19/22'

datetime_object = datetime.strptime(datetime_str, '%m/%d/%y')

# %%
index_1 = date_arr.index('01/01/2020')
index_2 = date_arr.index('12/31/2020')
date_arr[index_1:index_2+1]
# Out:
# ['01/01/2020',
#  '01/02/2020',
#  '01/03/2020',
#  '01/04/2020',
#  '01/05/2020',
#  '01/06/2020',
#  '01/07/2020',
#  '01/08/2020',
#  '01/09/2020',
#  '01/10/2020',
#  '01/11/2020',
#  '01/12/2020',
#  '01/13/2020',
#  '01/14/2020',
#  '01/15/2020',
#  '01/16/2020',
#  '01/17/2020',
#  '01/18/2020',
#  '01/19/2020',
#  '01/20/2020',
#  '01/21/2020',
#  '01/22/2020',
#  '01/23/2020',
#  '01/24/2020',
#  '01/25/2020',
#  '01/26/2020',
#  '01/27/2020',
#  '01/28/2020',
#  '01/29/2020',
#  '01/30/2020',
#  '01/31/2020',
#  '02/01/2020',
#  '02/02/2020',
#  '02/03/2020',
#  '02/04/2020',
#  '02/05/2020',
#  '02/06/2020',
#  '02/07/2020',
#  '02/08/2020',
#  '02/09/2020',
#  '02/10/2020',
#  '02/11/2020',
#  '02/12/2020',
#  '02/13/2020',
#  '02/14/2020',
#  '02/15/2020',
#  '02/16/2020',
#  '02/17/2020',
#  '02/18/2020',
#  '02/19/2020',
#  '02/20/2020',
#  '02/21/2020',
#  '02/22/2020',
#  '02/23/2020',
#  '02/24/2020',
#  '02/25/2020',
#  '02/26/2020',
#  '02/27/2020',
#  '02/28/2020',
#  '02/29/2020',
#  '03/01/2020',
#  '03/02/2020',
#  '03/03/2020',
#  '03/04/2020',
#  '03/05/2020',
#  '03/06/2020',
#  '03/07/2020',
#  '03/08/2020',
#  '03/09/2020',
#  '03/10/2020',
#  '03/11/2020',
#  '03/12/2020',
#  '03/13/2020',
#  '03/14/2020',
#  '03/15/2020',
#  '03/16/2020',
#  '03/17/2020',
#  '03/18/2020',
#  '03/19/2020',
#  '03/20/2020',
#  '03/21/2020',
#  '03/22/2020',
#  '03/23/2020',
#  '03/24/2020',
#  '03/25/2020',
#  '03/26/2020',
#  '03/27/2020',
#  '03/28/2020',
#  '03/29/2020',
#  '03/30/2020',
#  '03/31/2020',
#  '04/01/2020',
#  '04/02/2020',
#  '04/03/2020',
#  '04/04/2020',
#  '04/05/2020',
#  '04/06/2020',
#  '04/07/2020',
#  '04/08/2020',
#  '04/09/2020',
#  '04/10/2020',
#  '04/11/2020',
#  '04/12/2020',
#  '04/13/2020',
#  '04/14/2020',
#  '04/15/2020',
#  '04/16/2020',
#  '04/17/2020',
#  '04/18/2020',
#  '04/19/2020',
#  '04/20/2020',
#  '04/21/2020',
#  '04/22/2020',
#  '04/23/2020',
#  '04/24/2020',
#  '04/25/2020',
#  '04/26/2020',
#  '04/27/2020',
#  '04/28/2020',
#  '04/29/2020',
#  '04/30/2020',
#  '05/01/2020',
#  '05/02/2020',
#  '05/03/2020',
#  '05/04/2020',
#  '05/05/2020',
#  '05/06/2020',
#  '05/07/2020',
#  '05/08/2020',
#  '05/09/2020',
#  '05/10/2020',
#  '05/11/2020',
#  '05/12/2020',
#  '05/13/2020',
#  '05/14/2020',
#  '05/15/2020',
#  '05/16/2020',
#  '05/17/2020',
#  '05/18/2020',
#  '05/19/2020',
#  '05/20/2020',
#  '05/21/2020',
#  '05/22/2020',
#  '05/23/2020',
#  '05/24/2020',
#  '05/25/2020',
#  '05/26/2020',
#  '05/27/2020',
#  '05/28/2020',
#  '05/29/2020',
#  '05/30/2020',
#  '05/31/2020',
#  '06/01/2020',
#  '06/02/2020',
#  '06/03/2020',
#  '06/04/2020',
#  '06/05/2020',
#  '06/06/2020',
#  '06/07/2020',
#  '06/08/2020',
#  '06/09/2020',
#  '06/10/2020',
#  '06/11/2020',
#  '06/12/2020',
#  '06/13/2020',
#  '06/14/2020',
#  '06/15/2020',
#  '06/16/2020',
#  '06/17/2020',
#  '06/18/2020',
#  '06/19/2020',
#  '06/20/2020',
#  '06/21/2020',
#  '06/22/2020',
#  '06/23/2020',
#  '06/24/2020',
#  '06/25/2020',
#  '06/26/2020',
#  '06/27/2020',
#  '06/28/2020',
#  '06/29/2020',
#  '06/30/2020',
#  '07/01/2020',
#  '07/02/2020',
#  '07/03/2020',
#  '07/04/2020',
#  '07/05/2020',
#  '07/06/2020',
#  '07/07/2020',
#  '07/08/2020',
#  '07/09/2020',
#  '07/10/2020',
#  '07/11/2020',
#  '07/12/2020',
#  '07/13/2020',
#  '07/14/2020',
#  '07/15/2020',
#  '07/16/2020',
#  '07/17/2020',
#  '07/18/2020',
#  '07/19/2020',
#  '07/20/2020',
#  '07/21/2020',
#  '07/22/2020',
#  '07/23/2020',
#  '07/24/2020',
#  '07/25/2020',
#  '07/26/2020',
#  '07/27/2020',
#  '07/28/2020',
#  '07/29/2020',
#  '07/30/2020',
#  '07/31/2020',
#  '08/01/2020',
#  '08/02/2020',
#  '08/03/2020',
#  '08/04/2020',
#  '08/05/2020',
#  '08/06/2020',
#  '08/07/2020',
#  '08/08/2020',
#  '08/09/2020',
#  '08/10/2020',
#  '08/11/2020',
#  '08/12/2020',
#  '08/13/2020',
#  '08/14/2020',
#  '08/15/2020',
#  '08/16/2020',
#  '08/17/2020',
#  '08/18/2020',
#  '08/19/2020',
#  '08/20/2020',
#  '08/21/2020',
#  '08/22/2020',
#  '08/23/2020',
#  '08/24/2020',
#  '08/25/2020',
#  '08/26/2020',
#  '08/27/2020',
#  '08/28/2020',
#  '08/29/2020',
#  '08/30/2020',
#  '08/31/2020',
#  '09/01/2020',
#  '09/02/2020',
#  '09/03/2020',
#  '09/04/2020',
#  '09/05/2020',
#  '09/06/2020',
#  '09/07/2020',
#  '09/08/2020',
#  '09/09/2020',
#  '09/10/2020',
#  '09/11/2020',
#  '09/12/2020',
#  '09/13/2020',
#  '09/14/2020',
#  '09/15/2020',
#  '09/16/2020',
#  '09/17/2020',
#  '09/18/2020',
#  '09/19/2020',
#  '09/20/2020',
#  '09/21/2020',
#  '09/22/2020',
#  '09/23/2020',
#  '09/24/2020',
#  '09/25/2020',
#  '09/26/2020',
#  '09/27/2020',
#  '09/28/2020',
#  '09/29/2020',
#  '09/30/2020',
#  '10/01/2020',
#  '10/02/2020',
#  '10/03/2020',
#  '10/04/2020',
#  '10/05/2020',
#  '10/06/2020',
#  '10/07/2020',
#  '10/08/2020',
#  '10/09/2020',
#  '10/10/2020',
#  '10/11/2020',
#  '10/12/2020',
#  '10/13/2020',
#  '10/14/2020',
#  '10/15/2020',
#  '10/16/2020',
#  '10/17/2020',
#  '10/18/2020',
#  '10/19/2020',
#  '10/20/2020',
#  '10/21/2020',
#  '10/22/2020',
#  '10/23/2020',
#  '10/24/2020',
#  '10/25/2020',
#  '10/26/2020',
#  '10/27/2020',
#  '10/28/2020',
#  '10/29/2020',
#  '10/30/2020',
#  '10/31/2020',
#  '11/01/2020',
#  '11/02/2020',
#  '11/03/2020',
#  '11/04/2020',
#  '11/05/2020',
#  '11/06/2020',
#  '11/07/2020',
#  '11/08/2020',
#  '11/09/2020',
#  '11/10/2020',
#  '11/11/2020',
#  '11/12/2020',
#  '11/13/2020',
#  '11/14/2020',
#  '11/15/2020',
#  '11/16/2020',
#  '11/17/2020',
#  '11/18/2020',
#  '11/19/2020',
#  '11/20/2020',
#  '11/21/2020',
#  '11/22/2020',
#  '11/23/2020',
#  '11/24/2020',
#  '11/25/2020',
#  '11/26/2020',
#  '11/27/2020',
#  '11/28/2020',
#  '11/29/2020',
#  '11/30/2020',
#  '12/01/2020',
#  '12/02/2020',
#  '12/03/2020',
#  '12/04/2020',
#  '12/05/2020',
#  '12/06/2020',
#  '12/07/2020',
#  '12/08/2020',
#  '12/09/2020',
#  '12/10/2020',
#  '12/11/2020',
#  '12/12/2020',
#  '12/13/2020',
#  '12/14/2020',
#  '12/15/2020',
#  '12/16/2020',
#  '12/17/2020',
#  '12/18/2020',
#  '12/19/2020',
#  '12/20/2020',
#  '12/21/2020',
#  '12/22/2020',
#  '12/23/2020',
#  '12/24/2020',
#  '12/25/2020',
#  '12/26/2020',
#  '12/27/2020',
#  '12/28/2020',
#  '12/29/2020',
#  '12/30/2020',
#  '12/31/2020']

# %%
#tomcat lat and lon

tomcat_lat = [87.86, 85.10, 82.31, 79.53, 76.74,
        73.95, 71.16, 68.37, 65.58, 62.79,
        60.00, 57.21, 54.42, 51.63, 48.84,
        46.04, 43.25, 40.46, 37.67, 34.88,
        32.09, 29.30, 26.51, 23.72, 20.93,
        18.14, 15.35, 12.56,  9.77,  6.98,
         4.19,  1.40, -1.40, -4.19, -6.98,
        -9.77,-12.56,-15.35,-18.14,-20.93,
       -23.72,-26.51,-29.30,-32.09,-34.88,
       -37.67,-40.46,-43.25,-46.04,-48.84,
       -51.63,-54.42,-57.21,-60.00,-62.79,
       -65.58,-68.37,-71.16,-73.95,-76.74,
       -79.53,-82.31,-85.10,-87.86]

tomcat_lon_360 = np.arange(0,360,2.8125)

tomcat_lon = []
new_lon = 0

for i in range(len(tomcat_lon_360)):
    if tomcat_lon_360[i] > 180:
        new_lon = tomcat_lon_360[i]-360
    else:
        new_lon = tomcat_lon_360[i]
    tomcat_lon = np.append(tomcat_lon,new_lon)
    
tomcat_lon = np.sort(tomcat_lon)

# %%
print('min and max lat = ', np.min(lat_1d),np.max(lat_1d))
print('min and max lon = ', np.min(lon_1d),np.max(lon_1d))
X,Y = np.meshgrid (lon_1d,lat_1d)
for i in range(len(tomcat_lat)):
    for j in range(len(tomcat_lon)):
        flag = (tomcat_lat[i]>np.min(lat_1d) and tomcat_lat[i]<np.max(lat_1d) and tomcat_lon[j]>np.min(lon_1d) and tomcat_lon[j]<np.max(lon_1d))
        if flag == True:
            print(flag)
            lat_point = tomcat_lat[i]
            lon_point = tomcat_lon[j]
            data = snow_depth_annual[0,:,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/m6/qj3v2qcs35d7x8gdhqzsc7280000gn/T/ipykernel_12971/2501367534.py in <module>
# ----> 1 print('min and max lat = ', np.min(lat_1d),np.max(lat_1d))
#       2 print('min and max lon = ', np.min(lon_1d),np.max(lon_1d))
#       3 X,Y = np.meshgrid (lon_1d,lat_1d)
#       4 for i in range(len(tomcat_lat)):
#       5     for j in range(len(tomcat_lon)):
#
# NameError: name 'np' is not defined

# %%
np.shape(X)

# %%
np.shape(X)

# %%
a = np.array([12,12,13,4,5,6])
np.where(a==4)
# Out:
# (array([3]),)

# %%
lat_org = np.sort(lat.flatten())
lon_org = np.sort(lon.flatten())

lat_1d = lat.flatten();
lon_1d = lon.flatten();

np.where(lat_org[10]==lat_1d)

#lat_org[0]
# Out:
# (array([     1,    359,    361,    721, 129599, 129959, 129961, 130319]),)

# %%
lat_org[0]
# Out:
# 29.896942

# %%
lat_org[360]
# Out:
# 32.09478

# %%
lat_1d[360]
# Out:
# 29.896942

# %%
for i in range(361):
    print('lon_original index = ', i)
    for j in range(361):
        if j!=i:
            flag = (lon[i,:] - lon[j,:] == 0)
    #print('value of flag = ', flag)
    #print('shape of flag = ', np.shape(flag))
            if flag.all() == True:
            #print('hello')
                print ('same data at other indices = ', j)
# Out:
# lon_original index =  0
# lon_original index =  1
# lon_original index =  2
# lon_original index =  3
# lon_original index =  4
# lon_original index =  5
# lon_original index =  6
# lon_original index =  7
# lon_original index =  8
# lon_original index =  9
# lon_original index =  10
# lon_original index =  11
# lon_original index =  12
# lon_original index =  13
# lon_original index =  14
# lon_original index =  15
# lon_original index =  16
# lon_original index =  17
# lon_original index =  18
# lon_original index =  19
# lon_original index =  20
# lon_original index =  21
# lon_original index =  22
# lon_original index =  23
# lon_original index =  24
# lon_original index =  25
# lon_original index =  26
# lon_original index =  27
# lon_original index =  28
# lon_original index =  29
# lon_original index =  30
# lon_original index =  31
# lon_original index =  32
# lon_original index =  33
# lon_original index =  34
# lon_original index =  35
# lon_original index =  36
# lon_original index =  37
# lon_original index =  38
# lon_original index =  39
# lon_original index =  40
# lon_original index =  41
# lon_original index =  42
# lon_original index =  43
# lon_original index =  44
# lon_original index =  45
# lon_original index =  46
# lon_original index =  47
# lon_original index =  48
# lon_original index =  49
# lon_original index =  50
# lon_original index =  51
# lon_original index =  52
# lon_original index =  53
# lon_original index =  54
# lon_original index =  55
# lon_original index =  56
# lon_original index =  57
# lon_original index =  58
# lon_original index =  59
# lon_original index =  60
# lon_original index =  61
# lon_original index =  62
# lon_original index =  63
# lon_original index =  64
# lon_original index =  65
# lon_original index =  66
# lon_original index =  67
# lon_original index =  68
# lon_original index =  69
# lon_original index =  70
# lon_original index =  71
# lon_original index =  72
# lon_original index =  73
# lon_original index =  74
# lon_original index =  75
# lon_original index =  76
# lon_original index =  77
# lon_original index =  78
# lon_original index =  79
# lon_original index =  80
# lon_original index =  81
# lon_original index =  82
# lon_original index =  83
# lon_original index =  84
# lon_original index =  85
# lon_original index =  86
# lon_original index =  87
# lon_original index =  88
# lon_original index =  89
# lon_original index =  90
# lon_original index =  91
# lon_original index =  92
# lon_original index =  93
# lon_original index =  94
# lon_original index =  95
# lon_original index =  96
# lon_original index =  97
# lon_original index =  98
# lon_original index =  99
# lon_original index =  100
# lon_original index =  101
# lon_original index =  102
# lon_original index =  103
# lon_original index =  104
# lon_original index =  105
# lon_original index =  106
# lon_original index =  107
# lon_original index =  108
# lon_original index =  109
# lon_original index =  110
# lon_original index =  111
# lon_original index =  112
# lon_original index =  113
# lon_original index =  114
# lon_original index =  115
# lon_original index =  116
# lon_original index =  117
# lon_original index =  118
# lon_original index =  119
# lon_original index =  120
# lon_original index =  121
# lon_original index =  122
# lon_original index =  123
# lon_original index =  124
# lon_original index =  125
# lon_original index =  126
# lon_original index =  127
# lon_original index =  128
# lon_original index =  129
# lon_original index =  130
# lon_original index =  131
# lon_original index =  132
# lon_original index =  133
# lon_original index =  134
# lon_original index =  135
# lon_original index =  136
# lon_original index =  137
# lon_original index =  138
# lon_original index =  139
# lon_original index =  140
# lon_original index =  141
# lon_original index =  142
# lon_original index =  143
# lon_original index =  144
# lon_original index =  145
# lon_original index =  146
# lon_original index =  147
# lon_original index =  148
# lon_original index =  149
# lon_original index =  150
# lon_original index =  151
# lon_original index =  152
# lon_original index =  153
# lon_original index =  154
# lon_original index =  155
# lon_original index =  156
# lon_original index =  157
# lon_original index =  158
# lon_original index =  159
# lon_original index =  160
# lon_original index =  161
# lon_original index =  162
# lon_original index =  163
# lon_original index =  164
# lon_original index =  165
# lon_original index =  166
# lon_original index =  167
# lon_original index =  168
# lon_original index =  169
# lon_original index =  170
# lon_original index =  171
# lon_original index =  172
# lon_original index =  173
# lon_original index =  174
# lon_original index =  175
# lon_original index =  176
# lon_original index =  177
# lon_original index =  178
# lon_original index =  179
# lon_original index =  180
# lon_original index =  181
# lon_original index =  182
# lon_original index =  183
# lon_original index =  184
# lon_original index =  185
# lon_original index =  186
# lon_original index =  187
# lon_original index =  188
# lon_original index =  189
# lon_original index =  190
# lon_original index =  191
# lon_original index =  192
# lon_original index =  193
# lon_original index =  194
# lon_original index =  195
# lon_original index =  196
# lon_original index =  197
# lon_original index =  198
# lon_original index =  199
# lon_original index =  200
# lon_original index =  201
# lon_original index =  202
# lon_original index =  203
# lon_original index =  204
# lon_original index =  205
# lon_original index =  206
# lon_original index =  207
# lon_original index =  208
# lon_original index =  209
# lon_original index =  210
# lon_original index =  211
# lon_original index =  212
# lon_original index =  213
# lon_original index =  214
# lon_original index =  215
# lon_original index =  216
# lon_original index =  217
# lon_original index =  218
# lon_original index =  219
# lon_original index =  220
# lon_original index =  221
# lon_original index =  222
# lon_original index =  223
# lon_original index =  224
# lon_original index =  225
# lon_original index =  226
# lon_original index =  227
# lon_original index =  228
# lon_original index =  229
# lon_original index =  230
# lon_original index =  231
# lon_original index =  232
# lon_original index =  233
# lon_original index =  234
# lon_original index =  235
# lon_original index =  236
# lon_original index =  237
# lon_original index =  238
# lon_original index =  239
# lon_original index =  240
# lon_original index =  241
# lon_original index =  242
# lon_original index =  243
# lon_original index =  244
# lon_original index =  245
# lon_original index =  246
# lon_original index =  247
# lon_original index =  248
# lon_original index =  249
# lon_original index =  250
# lon_original index =  251
# lon_original index =  252
# lon_original index =  253
# lon_original index =  254
# lon_original index =  255
# lon_original index =  256
# lon_original index =  257
# lon_original index =  258
# lon_original index =  259
# lon_original index =  260
# lon_original index =  261
# lon_original index =  262
# lon_original index =  263
# lon_original index =  264
# lon_original index =  265
# lon_original index =  266
# lon_original index =  267
# lon_original index =  268
# lon_original index =  269
# lon_original index =  270
# lon_original index =  271
# lon_original index =  272
# lon_original index =  273
# lon_original index =  274
# lon_original index =  275
# lon_original index =  276
# lon_original index =  277
# lon_original index =  278
# lon_original index =  279
# lon_original index =  280
# lon_original index =  281
# lon_original index =  282
# lon_original index =  283
# lon_original index =  284
# lon_original index =  285
# lon_original index =  286
# lon_original index =  287
# lon_original index =  288
# lon_original index =  289
# lon_original index =  290
# lon_original index =  291
# lon_original index =  292
# lon_original index =  293
# lon_original index =  294
# lon_original index =  295
# lon_original index =  296
# lon_original index =  297
# lon_original index =  298
# lon_original index =  299
# lon_original index =  300
# lon_original index =  301
# lon_original index =  302
# lon_original index =  303
# lon_original index =  304
# lon_original index =  305
# lon_original index =  306
# lon_original index =  307
# lon_original index =  308
# lon_original index =  309
# lon_original index =  310
# lon_original index =  311
# lon_original index =  312
# lon_original index =  313
# lon_original index =  314
# lon_original index =  315
# lon_original index =  316
# lon_original index =  317
# lon_original index =  318
# lon_original index =  319
# lon_original index =  320
# lon_original index =  321
# lon_original index =  322
# lon_original index =  323
# lon_original index =  324
# lon_original index =  325
# lon_original index =  326
# lon_original index =  327
# lon_original index =  328
# lon_original index =  329
# lon_original index =  330
# lon_original index =  331
# lon_original index =  332
# lon_original index =  333
# lon_original index =  334
# lon_original index =  335
# lon_original index =  336
# lon_original index =  337
# lon_original index =  338
# lon_original index =  339
# lon_original index =  340
# lon_original index =  341
# lon_original index =  342
# lon_original index =  343
# lon_original index =  344
# lon_original index =  345
# lon_original index =  346
# lon_original index =  347
# lon_original index =  348
# lon_original index =  349
# lon_original index =  350
# lon_original index =  351
# lon_original index =  352
# lon_original index =  353
# lon_original index =  354
# lon_original index =  355
# lon_original index =  356
# lon_original index =  357
# lon_original index =  358
# lon_original index =  359
# lon_original index =  360

# %%
for i in range(361):
    print('lat_original index = ', i)
    for j in range(361):
        if j!=i:
            flag = (lat[i,:] - lat[j,:] == 0)
    #print('value of flag = ', flag)
    #print('shape of flag = ', np.shape(flag))
            if flag.all() == True:
            #print('hello')
                print ('same data at other indices = ', j)
# Out:
# lat_original index =  0
# same data at other indices =  360
# lat_original index =  1
# same data at other indices =  359
# lat_original index =  2
# same data at other indices =  358
# lat_original index =  3
# same data at other indices =  357
# lat_original index =  4
# same data at other indices =  356
# lat_original index =  5
# same data at other indices =  355
# lat_original index =  6
# same data at other indices =  354
# lat_original index =  7
# same data at other indices =  353
# lat_original index =  8
# same data at other indices =  352
# lat_original index =  9
# same data at other indices =  351
# lat_original index =  10
# same data at other indices =  350
# lat_original index =  11
# same data at other indices =  349
# lat_original index =  12
# same data at other indices =  348
# lat_original index =  13
# same data at other indices =  347
# lat_original index =  14
# same data at other indices =  346
# lat_original index =  15
# same data at other indices =  345
# lat_original index =  16
# same data at other indices =  344
# lat_original index =  17
# same data at other indices =  343
# lat_original index =  18
# same data at other indices =  342
# lat_original index =  19
# same data at other indices =  341
# lat_original index =  20
# same data at other indices =  340
# lat_original index =  21
# same data at other indices =  339
# lat_original index =  22
# same data at other indices =  338
# lat_original index =  23
# same data at other indices =  337
# lat_original index =  24
# same data at other indices =  336
# lat_original index =  25
# same data at other indices =  335
# lat_original index =  26
# same data at other indices =  334
# lat_original index =  27
# same data at other indices =  333
# lat_original index =  28
# same data at other indices =  332
# lat_original index =  29
# same data at other indices =  331
# lat_original index =  30
# same data at other indices =  330
# lat_original index =  31
# same data at other indices =  329
# lat_original index =  32
# same data at other indices =  328
# lat_original index =  33
# same data at other indices =  327
# lat_original index =  34
# same data at other indices =  326
# lat_original index =  35
# same data at other indices =  325
# lat_original index =  36
# same data at other indices =  324
# lat_original index =  37
# same data at other indices =  323
# lat_original index =  38
# same data at other indices =  322
# lat_original index =  39
# same data at other indices =  321
# lat_original index =  40
# same data at other indices =  320
# lat_original index =  41
# same data at other indices =  319
# lat_original index =  42
# same data at other indices =  318
# lat_original index =  43
# same data at other indices =  317
# lat_original index =  44
# same data at other indices =  316
# lat_original index =  45
# same data at other indices =  315
# lat_original index =  46
# same data at other indices =  314
# lat_original index =  47
# same data at other indices =  313
# lat_original index =  48
# same data at other indices =  312
# lat_original index =  49
# same data at other indices =  311
# lat_original index =  50
# same data at other indices =  310
# lat_original index =  51
# same data at other indices =  309
# lat_original index =  52
# same data at other indices =  308
# lat_original index =  53
# same data at other indices =  307
# lat_original index =  54
# same data at other indices =  306
# lat_original index =  55
# same data at other indices =  305
# lat_original index =  56
# same data at other indices =  304
# lat_original index =  57
# same data at other indices =  303
# lat_original index =  58
# same data at other indices =  302
# lat_original index =  59
# same data at other indices =  301
# lat_original index =  60
# same data at other indices =  300
# lat_original index =  61
# same data at other indices =  299
# lat_original index =  62
# same data at other indices =  298
# lat_original index =  63
# same data at other indices =  297
# lat_original index =  64
# same data at other indices =  296
# lat_original index =  65
# same data at other indices =  295
# lat_original index =  66
# same data at other indices =  294
# lat_original index =  67
# same data at other indices =  293
# lat_original index =  68
# same data at other indices =  292
# lat_original index =  69
# same data at other indices =  291
# lat_original index =  70
# same data at other indices =  290
# lat_original index =  71
# same data at other indices =  289
# lat_original index =  72
# same data at other indices =  288
# lat_original index =  73
# same data at other indices =  287
# lat_original index =  74
# same data at other indices =  286
# lat_original index =  75
# same data at other indices =  285
# lat_original index =  76
# same data at other indices =  284
# lat_original index =  77
# same data at other indices =  283
# lat_original index =  78
# same data at other indices =  282
# lat_original index =  79
# same data at other indices =  281
# lat_original index =  80
# same data at other indices =  280
# lat_original index =  81
# same data at other indices =  279
# lat_original index =  82
# same data at other indices =  278
# lat_original index =  83
# same data at other indices =  277
# lat_original index =  84
# same data at other indices =  276
# lat_original index =  85
# same data at other indices =  275
# lat_original index =  86
# same data at other indices =  274
# lat_original index =  87
# same data at other indices =  273
# lat_original index =  88
# same data at other indices =  272
# lat_original index =  89
# same data at other indices =  271
# lat_original index =  90
# same data at other indices =  270
# lat_original index =  91
# same data at other indices =  269
# lat_original index =  92
# same data at other indices =  268
# lat_original index =  93
# same data at other indices =  267
# lat_original index =  94
# same data at other indices =  266
# lat_original index =  95
# same data at other indices =  265
# lat_original index =  96
# same data at other indices =  264
# lat_original index =  97
# same data at other indices =  263
# lat_original index =  98
# same data at other indices =  262
# lat_original index =  99
# same data at other indices =  261
# lat_original index =  100
# same data at other indices =  260
# lat_original index =  101
# same data at other indices =  259
# lat_original index =  102
# same data at other indices =  258
# lat_original index =  103
# same data at other indices =  257
# lat_original index =  104
# same data at other indices =  256
# lat_original index =  105
# same data at other indices =  255
# lat_original index =  106
# same data at other indices =  254
# lat_original index =  107
# same data at other indices =  253
# lat_original index =  108
# same data at other indices =  252
# lat_original index =  109
# same data at other indices =  251
# lat_original index =  110
# same data at other indices =  250
# lat_original index =  111
# same data at other indices =  249
# lat_original index =  112
# same data at other indices =  248
# lat_original index =  113
# same data at other indices =  247
# lat_original index =  114
# same data at other indices =  246
# lat_original index =  115
# same data at other indices =  245
# lat_original index =  116
# same data at other indices =  244
# lat_original index =  117
# same data at other indices =  243
# lat_original index =  118
# same data at other indices =  242
# lat_original index =  119
# same data at other indices =  241
# lat_original index =  120
# same data at other indices =  240
# lat_original index =  121
# same data at other indices =  239
# lat_original index =  122
# same data at other indices =  238
# lat_original index =  123
# same data at other indices =  237
# lat_original index =  124
# same data at other indices =  236
# lat_original index =  125
# same data at other indices =  235
# lat_original index =  126
# same data at other indices =  234
# lat_original index =  127
# same data at other indices =  233
# lat_original index =  128
# same data at other indices =  232
# lat_original index =  129
# same data at other indices =  231
# lat_original index =  130
# same data at other indices =  230
# lat_original index =  131
# same data at other indices =  229
# lat_original index =  132
# same data at other indices =  228
# lat_original index =  133
# same data at other indices =  227
# lat_original index =  134
# same data at other indices =  226
# lat_original index =  135
# same data at other indices =  225
# lat_original index =  136
# same data at other indices =  224
# lat_original index =  137
# same data at other indices =  223
# lat_original index =  138
# same data at other indices =  222
# lat_original index =  139
# same data at other indices =  221
# lat_original index =  140
# same data at other indices =  220
# lat_original index =  141
# same data at other indices =  219
# lat_original index =  142
# same data at other indices =  218
# lat_original index =  143
# same data at other indices =  217
# lat_original index =  144
# same data at other indices =  216
# lat_original index =  145
# same data at other indices =  215
# lat_original index =  146
# same data at other indices =  214
# lat_original index =  147
# same data at other indices =  213
# lat_original index =  148
# same data at other indices =  212
# lat_original index =  149
# same data at other indices =  211
# lat_original index =  150
# same data at other indices =  210
# lat_original index =  151
# same data at other indices =  209
# lat_original index =  152
# same data at other indices =  208
# lat_original index =  153
# same data at other indices =  207
# lat_original index =  154
# same data at other indices =  206
# lat_original index =  155
# same data at other indices =  205
# lat_original index =  156
# same data at other indices =  204
# lat_original index =  157
# same data at other indices =  203
# lat_original index =  158
# same data at other indices =  202
# lat_original index =  159
# same data at other indices =  201
# lat_original index =  160
# same data at other indices =  200
# lat_original index =  161
# same data at other indices =  199
# lat_original index =  162
# same data at other indices =  198
# lat_original index =  163
# same data at other indices =  197
# lat_original index =  164
# same data at other indices =  196
# lat_original index =  165
# same data at other indices =  195
# lat_original index =  166
# same data at other indices =  194
# lat_original index =  167
# same data at other indices =  193
# lat_original index =  168
# same data at other indices =  192
# lat_original index =  169
# same data at other indices =  191
# lat_original index =  170
# same data at other indices =  190
# lat_original index =  171
# same data at other indices =  189
# lat_original index =  172
# same data at other indices =  188
# lat_original index =  173
# same data at other indices =  187
# lat_original index =  174
# same data at other indices =  186
# lat_original index =  175
# same data at other indices =  185
# lat_original index =  176
# same data at other indices =  184
# lat_original index =  177
# same data at other indices =  183
# lat_original index =  178
# same data at other indices =  182
# lat_original index =  179
# same data at other indices =  181
# lat_original index =  180
# lat_original index =  181
# same data at other indices =  179
# lat_original index =  182
# same data at other indices =  178
# lat_original index =  183
# same data at other indices =  177
# lat_original index =  184
# same data at other indices =  176
# lat_original index =  185
# same data at other indices =  175
# lat_original index =  186
# same data at other indices =  174
# lat_original index =  187
# same data at other indices =  173
# lat_original index =  188
# same data at other indices =  172
# lat_original index =  189
# same data at other indices =  171
# lat_original index =  190
# same data at other indices =  170
# lat_original index =  191
# same data at other indices =  169
# lat_original index =  192
# same data at other indices =  168
# lat_original index =  193
# same data at other indices =  167
# lat_original index =  194
# same data at other indices =  166
# lat_original index =  195
# same data at other indices =  165
# lat_original index =  196
# same data at other indices =  164
# lat_original index =  197
# same data at other indices =  163
# lat_original index =  198
# same data at other indices =  162
# lat_original index =  199
# same data at other indices =  161
# lat_original index =  200
# same data at other indices =  160
# lat_original index =  201
# same data at other indices =  159
# lat_original index =  202
# same data at other indices =  158
# lat_original index =  203
# same data at other indices =  157
# lat_original index =  204
# same data at other indices =  156
# lat_original index =  205
# same data at other indices =  155
# lat_original index =  206
# same data at other indices =  154
# lat_original index =  207
# same data at other indices =  153
# lat_original index =  208
# same data at other indices =  152
# lat_original index =  209
# same data at other indices =  151
# lat_original index =  210
# same data at other indices =  150
# lat_original index =  211
# same data at other indices =  149
# lat_original index =  212
# same data at other indices =  148
# lat_original index =  213
# same data at other indices =  147
# lat_original index =  214
# same data at other indices =  146
# lat_original index =  215
# same data at other indices =  145
# lat_original index =  216
# same data at other indices =  144
# lat_original index =  217
# same data at other indices =  143
# lat_original index =  218
# same data at other indices =  142
# lat_original index =  219
# same data at other indices =  141
# lat_original index =  220
# same data at other indices =  140
# lat_original index =  221
# same data at other indices =  139
# lat_original index =  222
# same data at other indices =  138
# lat_original index =  223
# same data at other indices =  137
# lat_original index =  224
# same data at other indices =  136
# lat_original index =  225
# same data at other indices =  135
# lat_original index =  226
# same data at other indices =  134
# lat_original index =  227
# same data at other indices =  133
# lat_original index =  228
# same data at other indices =  132
# lat_original index =  229
# same data at other indices =  131
# lat_original index =  230
# same data at other indices =  130
# lat_original index =  231
# same data at other indices =  129
# lat_original index =  232
# same data at other indices =  128
# lat_original index =  233
# same data at other indices =  127
# lat_original index =  234
# same data at other indices =  126
# lat_original index =  235
# same data at other indices =  125
# lat_original index =  236
# same data at other indices =  124
# lat_original index =  237
# same data at other indices =  123
# lat_original index =  238
# same data at other indices =  122
# lat_original index =  239
# same data at other indices =  121
# lat_original index =  240
# same data at other indices =  120
# lat_original index =  241
# same data at other indices =  119
# lat_original index =  242
# same data at other indices =  118
# lat_original index =  243
# same data at other indices =  117
# lat_original index =  244
# same data at other indices =  116
# lat_original index =  245
# same data at other indices =  115
# lat_original index =  246
# same data at other indices =  114
# lat_original index =  247
# same data at other indices =  113
# lat_original index =  248
# same data at other indices =  112
# lat_original index =  249
# same data at other indices =  111
# lat_original index =  250
# same data at other indices =  110
# lat_original index =  251
# same data at other indices =  109
# lat_original index =  252
# same data at other indices =  108
# lat_original index =  253
# same data at other indices =  107
# lat_original index =  254
# same data at other indices =  106
# lat_original index =  255
# same data at other indices =  105
# lat_original index =  256
# same data at other indices =  104
# lat_original index =  257
# same data at other indices =  103
# lat_original index =  258
# same data at other indices =  102
# lat_original index =  259
# same data at other indices =  101
# lat_original index =  260
# same data at other indices =  100
# lat_original index =  261
# same data at other indices =  99
# lat_original index =  262
# same data at other indices =  98
# lat_original index =  263
# same data at other indices =  97
# lat_original index =  264
# same data at other indices =  96
# lat_original index =  265
# same data at other indices =  95
# lat_original index =  266
# same data at other indices =  94
# lat_original index =  267
# same data at other indices =  93
# lat_original index =  268
# same data at other indices =  92
# lat_original index =  269
# same data at other indices =  91
# lat_original index =  270
# same data at other indices =  90
# lat_original index =  271
# same data at other indices =  89
# lat_original index =  272
# same data at other indices =  88
# lat_original index =  273
# same data at other indices =  87
# lat_original index =  274
# same data at other indices =  86
# lat_original index =  275
# same data at other indices =  85
# lat_original index =  276
# same data at other indices =  84
# lat_original index =  277
# same data at other indices =  83
# lat_original index =  278
# same data at other indices =  82
# lat_original index =  279
# same data at other indices =  81
# lat_original index =  280
# same data at other indices =  80
# lat_original index =  281
# same data at other indices =  79
# lat_original index =  282
# same data at other indices =  78
# lat_original index =  283
# same data at other indices =  77
# lat_original index =  284
# same data at other indices =  76
# lat_original index =  285
# same data at other indices =  75
# lat_original index =  286
# same data at other indices =  74
# lat_original index =  287
# same data at other indices =  73
# lat_original index =  288
# same data at other indices =  72
# lat_original index =  289
# same data at other indices =  71
# lat_original index =  290
# same data at other indices =  70
# lat_original index =  291
# same data at other indices =  69
# lat_original index =  292
# same data at other indices =  68
# lat_original index =  293
# same data at other indices =  67
# lat_original index =  294
# same data at other indices =  66
# lat_original index =  295
# same data at other indices =  65
# lat_original index =  296
# same data at other indices =  64
# lat_original index =  297
# same data at other indices =  63
# lat_original index =  298
# same data at other indices =  62
# lat_original index =  299
# same data at other indices =  61
# lat_original index =  300
# same data at other indices =  60
# lat_original index =  301
# same data at other indices =  59
# lat_original index =  302
# same data at other indices =  58
# lat_original index =  303
# same data at other indices =  57
# lat_original index =  304
# same data at other indices =  56
# lat_original index =  305
# same data at other indices =  55
# lat_original index =  306
# same data at other indices =  54
# lat_original index =  307
# same data at other indices =  53
# lat_original index =  308
# same data at other indices =  52
# lat_original index =  309
# same data at other indices =  51
# lat_original index =  310
# same data at other indices =  50
# lat_original index =  311
# same data at other indices =  49
# lat_original index =  312
# same data at other indices =  48
# lat_original index =  313
# same data at other indices =  47
# lat_original index =  314
# same data at other indices =  46
# lat_original index =  315
# same data at other indices =  45
# lat_original index =  316
# same data at other indices =  44
# lat_original index =  317
# same data at other indices =  43
# lat_original index =  318
# same data at other indices =  42
# lat_original index =  319
# same data at other indices =  41
# lat_original index =  320
# same data at other indices =  40
# lat_original index =  321
# same data at other indices =  39
# lat_original index =  322
# same data at other indices =  38
# lat_original index =  323
# same data at other indices =  37
# lat_original index =  324
# same data at other indices =  36
# lat_original index =  325
# same data at other indices =  35
# lat_original index =  326
# same data at other indices =  34
# lat_original index =  327
# same data at other indices =  33
# lat_original index =  328
# same data at other indices =  32
# lat_original index =  329
# same data at other indices =  31
# lat_original index =  330
# same data at other indices =  30
# lat_original index =  331
# same data at other indices =  29
# lat_original index =  332
# same data at other indices =  28
# lat_original index =  333
# same data at other indices =  27
# lat_original index =  334
# same data at other indices =  26
# lat_original index =  335
# same data at other indices =  25
# lat_original index =  336
# same data at other indices =  24
# lat_original index =  337
# same data at other indices =  23
# lat_original index =  338
# same data at other indices =  22
# lat_original index =  339
# same data at other indices =  21
# lat_original index =  340
# same data at other indices =  20
# lat_original index =  341
# same data at other indices =  19
# lat_original index =  342
# same data at other indices =  18
# lat_original index =  343
# same data at other indices =  17
# lat_original index =  344
# same data at other indices =  16
# lat_original index =  345
# same data at other indices =  15
# lat_original index =  346
# same data at other indices =  14
# lat_original index =  347
# same data at other indices =  13
# lat_original index =  348
# same data at other indices =  12
# lat_original index =  349
# same data at other indices =  11
# lat_original index =  350
# same data at other indices =  10
# lat_original index =  351
# same data at other indices =  9
# lat_original index =  352
# same data at other indices =  8
# lat_original index =  353
# same data at other indices =  7
# lat_original index =  354
# same data at other indices =  6
# lat_original index =  355
# same data at other indices =  5
# lat_original index =  356
# same data at other indices =  4
# lat_original index =  357
# same data at other indices =  3
# lat_original index =  358
# same data at other indices =  2
# lat_original index =  359
# same data at other indices =  1
# lat_original index =  360
# same data at other indices =  0

# %%
lat[2,:]
# Out:
# masked_array(data=[30.26389 , 30.448393, 30.632214, 30.815353, 30.997808,
#                    31.179575, 31.360653, 31.54104 , 31.720734, 31.89973 ,
#                    32.07803 , 32.25563 , 32.432526, 32.60872 , 32.784203,
#                    32.958977, 33.133038, 33.30638 , 33.479008, 33.650913,
#                    33.822098, 33.992554, 34.16228 , 34.331276, 34.499535,
#                    34.667057, 34.833836, 34.999874, 35.16516 , 35.3297  ,
#                    35.493484, 35.656513, 35.81878 , 35.98028 , 36.141018,
#                    36.300983, 36.460175, 36.61859 , 36.776222, 36.93307 ,
#                    37.08913 , 37.244396, 37.39887 , 37.55254 , 37.70541 ,
#                    37.85747 , 38.00872 , 38.159153, 38.30877 , 38.45756 ,
#                    38.605522, 38.752655, 38.898952, 39.04441 , 39.189022,
#                    39.332787, 39.475697, 39.61775 , 39.75894 , 39.89927 ,
#                    40.038723, 40.177303, 40.315002, 40.45182 , 40.58775 ,
#                    40.722782, 40.85692 , 40.99015 , 41.12248 , 41.25389 ,
#                    41.384384, 41.513958, 41.642605, 41.77032 , 41.8971  ,
#                    42.022934, 42.147823, 42.271763, 42.394745, 42.51676 ,
#                    42.637814, 42.757893, 42.876995, 42.995117, 43.11225 ,
#                    43.22839 , 43.343533, 43.457672, 43.570805, 43.68292 ,
#                    43.794018, 43.904095, 44.013138, 44.121147, 44.22812 ,
#                    44.334045, 44.43892 , 44.542736, 44.645496, 44.747185,
#                    44.847805, 44.947346, 45.045807, 45.143177, 45.239456,
#                    45.334637, 45.428715, 45.521683, 45.613537, 45.70427 ,
#                    45.79388 , 45.882362, 45.969707, 46.055912, 46.140972,
#                    46.22488 , 46.307632, 46.389225, 46.469654, 46.548912,
#                    46.62699 , 46.70389 , 46.779606, 46.854134, 46.927464,
#                    46.99959 , 47.070515, 47.140232, 47.208733, 47.276016,
#                    47.342075, 47.406906, 47.470505, 47.532867, 47.59399 ,
#                    47.653866, 47.71249 , 47.769863, 47.82598 , 47.880833,
#                    47.93442 , 47.98674 , 48.037785, 48.08755 , 48.13604 ,
#                    48.183243, 48.229156, 48.27378 , 48.31711 , 48.35914 ,
#                    48.399868, 48.439293, 48.47741 , 48.514217, 48.54971 ,
#                    48.58389 , 48.61675 , 48.648285, 48.6785  , 48.70739 ,
#                    48.73495 , 48.76118 , 48.78608 , 48.809643, 48.83187 ,
#                    48.85276 , 48.872307, 48.890514, 48.90738 , 48.9229  ,
#                    48.937077, 48.949905, 48.961388, 48.97152 , 48.980305,
#                    48.987736, 48.99382 , 48.99855 , 49.00193 , 49.00396 ,
#                    49.004635, 49.00396 , 49.00193 , 48.99855 , 48.99382 ,
#                    48.987736, 48.980305, 48.97152 , 48.961388, 48.949905,
#                    48.937077, 48.9229  , 48.90738 , 48.890514, 48.872307,
#                    48.85276 , 48.83187 , 48.809643, 48.78608 , 48.76118 ,
#                    48.73495 , 48.70739 , 48.6785  , 48.648285, 48.61675 ,
#                    48.58389 , 48.54971 , 48.514217, 48.47741 , 48.439293,
#                    48.399868, 48.35914 , 48.31711 , 48.27378 , 48.229156,
#                    48.183243, 48.13604 , 48.08755 , 48.037785, 47.98674 ,
#                    47.93442 , 47.880833, 47.82598 , 47.769863, 47.71249 ,
#                    47.653866, 47.59399 , 47.532867, 47.470505, 47.406906,
#                    47.342075, 47.276016, 47.208733, 47.140232, 47.070515,
#                    46.99959 , 46.927464, 46.854134, 46.779606, 46.70389 ,
#                    46.62699 , 46.548912, 46.469654, 46.389225, 46.307632,
#                    46.22488 , 46.140972, 46.055912, 45.969707, 45.882362,
#                    45.79388 , 45.70427 , 45.613537, 45.521683, 45.428715,
#                    45.334637, 45.239456, 45.143177, 45.045807, 44.947346,
#                    44.847805, 44.747185, 44.645496, 44.542736, 44.43892 ,
#                    44.334045, 44.22812 , 44.121147, 44.013138, 43.904095,
#                    43.794018, 43.68292 , 43.570805, 43.457672, 43.343533,
#                    43.22839 , 43.11225 , 42.995117, 42.876995, 42.757893,
#                    42.637814, 42.51676 , 42.394745, 42.271763, 42.147823,
#                    42.022934, 41.8971  , 41.77032 , 41.642605, 41.513958,
#                    41.384384, 41.25389 , 41.12248 , 40.99015 , 40.85692 ,
#                    40.722782, 40.58775 , 40.45182 , 40.315002, 40.177303,
#                    40.038723, 39.89927 , 39.75894 , 39.61775 , 39.475697,
#                    39.332787, 39.189022, 39.04441 , 38.898952, 38.752655,
#                    38.605522, 38.45756 , 38.30877 , 38.159153, 38.00872 ,
#                    37.85747 , 37.70541 , 37.55254 , 37.39887 , 37.244396,
#                    37.08913 , 36.93307 , 36.776222, 36.61859 , 36.460175,
#                    36.300983, 36.141018, 35.98028 , 35.81878 , 35.656513,
#                    35.493484, 35.3297  , 35.16516 , 34.999874, 34.833836,
#                    34.667057, 34.499535, 34.331276, 34.16228 , 33.992554,
#                    33.822098, 33.650913, 33.479008, 33.30638 , 33.133038,
#                    32.958977, 32.784203, 32.60872 , 32.432526, 32.25563 ,
#                    32.07803 , 31.89973 , 31.720734, 31.54104 , 31.360653,
#                    31.179575, 30.997808, 30.815353, 30.632214, 30.448393,
#                    30.26389 ],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
lat_1d = lat.flatten();
lon_1d = lon.flatten();

snowdepth_1d = snow_depth.flatten()*100

# %%
snowdepth_1d.reshape((12,361,361))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/m6/qj3v2qcs35d7x8gdhqzsc7280000gn/T/ipykernel_12971/3276268615.py in <module>
# ----> 1 snowdepth_1d.reshape((12,361,361))
#
# ValueError: cannot reshape array of size 47567165 into shape (12,361,361)

# %%
np.shape(snow_depth_annual)
# Out:
# (12, 361, 361)
