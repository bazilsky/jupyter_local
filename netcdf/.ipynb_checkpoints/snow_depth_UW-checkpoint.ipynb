# %%
from netCDF4 import Dataset
import iris
import numpy as np
import pylab as plt
import cartopy.crs as ccrs
import cartopy.feature
filename = '/Users/ananth/Downloads/snow_depth.nc'

# %%
cube = iris.load(filename)

# %%
cube
# Out:
# [<iris 'Cube' of Longitude / (unknown) (-- : 46; -- : 44)>,
# <iris 'Cube' of Snow depth in snow water equivalent / (unknown) (-- : 36; -- : 46; -- : 44)>,
# <iris 'Cube' of Latitude / (unknown) (-- : 46; -- : 44)>]
