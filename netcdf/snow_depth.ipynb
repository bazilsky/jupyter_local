# %%
import iris
import glob
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature

# %%
path = '/Users/ananth/Downloads/amsr/'
files = glob.glob(path+'*.nc') # snow depth amsr files
print(files)

path2= '/Users/ananth/Downloads/amsr/dec2012/snowdepth_amsr2_2012121v1.1.nc'
latlon = iris.load(path2)

path3 = '/Users/ananth/Downloads/amsr/mar2013/snowdepth_amsr2_2013031v1.1.nc'

test_cube = iris.load(path3)
test_cube
# Out:
# ['/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220303v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220311v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220327v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220313v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220301v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220329v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220325v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220321v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220305v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220317v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220309v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220331v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220323v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220315v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220319v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220307v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220326v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220302v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220310v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220328v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220324v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220312v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220304v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220308v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220316v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220320v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220314v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220306v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220318v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220330v1.1.nc', '/Users/ananth/Downloads/amsr/SnowDepth_amsr2_20220322v1.1.nc']
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lat' invalid units 'deg'
#   warnings.warn(msg)
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lon' invalid units 'deg'
#   warnings.warn(msg)
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lat' invalid units 'deg'
#   warnings.warn(msg)
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lon' invalid units 'deg'
#   warnings.warn(msg)
# [<iris 'Cube' of lat / (unknown) (-- : 448; -- : 304)>,
# <iris 'Cube' of lon / (unknown) (-- : 448; -- : 304)>,
# <iris 'Cube' of snow_depth_unc / (cm) (-- : 448; -- : 304)>,
# <iris 'Cube' of snow_depth / (cm) (-- : 448; -- : 304)>,
# <iris 'Cube' of Time / (seconds since 1970-01-01) (-- : 1)>]

# %%
lon = latlon[0].data
lat = latlon[1].data
np.shape(lat)

snow_depth = iris.load(files[0])[1]
snow_depth = snow_depth.data
np.shape(lat)

latlon


np.min(l)
# Out:
# 31.102669

# %%
fig, ax = plt.subplots(1,1,figsize=(8,8),  subplot_kw={'projection': ccrs.NorthPolarStereo()})

"""
ax.scatter([x[0] for x in max_coords[:-1]],
           [x[1] for x in max_coords[:-1]],
           color='k',
           s=50,
           marker='x',transform=ccrs.PlateCarree(),zorder=5,
           label='BSH Center 1980-2020')
"""

ax.set_extent([-180, 180, 90, 0], ccrs.PlateCarree())
ax.gridlines()

ax.add_feature(cartopy.feature.LAND, edgecolor='black',zorder=1)
#ax.add_feature(cartopy.feature.OCEAN)

#for i in range(448):
 #   for j in range(304):
  #      ax.scatter(lat[i][j],lon[i][j],color = 'k',s=50,marker = 'x',transform=ccrs.PlateCarree(),zorder=5)
ax.scatter(lon, lat,color = 'k',s = 5, marker = 'x',transform = ccrs.PlateCarree(),zorder = 5)
#ax.scatter(lat[])


ax.legend(fontsize='x-large')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
np.shape(lat.flatten())
# Out:
# (136192,)

# %%
cube[0]
# Out:
# <iris 'Cube' of snow_depth_unc / (cm) (-- : 448; -- : 304)>

# %%
np.shape(cube[1].data)
# Out:
# (448, 304)

# %%
check1 = Dataset(files[1])

# %%
check1
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     description: Snow depth on Arctic sea ice from satellite radiometers (AMSR-E/2)
#     reference: Rostosky et al. (2018).:Snow Depth Retrieval on Arctic Sea Ice From Passive Microwave Radiometers
#                              —Improvements and Extensions to Multiyear Ice Using Lower Frequencies, Journal of Geophysical
#                              Research: Oceans, 123, doi.org/10.1029/2018JC014028
#     grid: NSIDC polar_stereographic grid
#     spatial_resolution: 25 km
#     temporal_resolution: Daily mean
#     proj4string: +proj=stere +lat_0=90 +lat_ts=90 +lon_0=-45 +k=1 +x_0=0 +y_0=0 +ellps=WGS84 +datum=WGS84 +units=m
#     lat_north: 90.0
#     lat_south: 31.102669
#     east_lon: 180.0
#     west_lon: -180.0
#     dimensions(sizes): xc(448), yc(304), time(1)
#     variables(dimensions): float32 snow_depth(xc, yc), float32 snow_depth_unc(xc, yc)
#     groups:

# %%
l = list(check1.dimensions.values())

# %%
print(l[0].points())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/m6/qj3v2qcs35d7x8gdhqzsc7280000gn/T/ipykernel_81259/3806122389.py in <module>
# ----> 1 print(l[0].points())
#
# AttributeError: 'netCDF4._netCDF4.Dimension' object has no attribute 'points'

# %%
path2= '/Users/ananth/Downloads/amsr/dec2012/snowdepth_amsr2_2012121v1.1.nc'
cube1 = iris.load(path2)
# Out:
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lon' invalid units 'deg'
#   warnings.warn(msg)
# /Users/ananth/miniconda3/envs/tensorflow_env/lib/python3.7/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lat' invalid units 'deg'
#   warnings.warn(msg)

# %%
cube1
# Out:
# [<iris 'Cube' of snow_depth_unc / (cm) (-- : 448; -- : 304)>,
# <iris 'Cube' of snow_depth / (cm) (-- : 448; -- : 304)>,
# <iris 'Cube' of lon / (unknown) (-- : 448; -- : 304)>,
# <iris 'Cube' of Time / (seconds since 1970-01-01) (-- : 1)>,
# <iris 'Cube' of lat / (unknown) (-- : 448; -- : 304)>]
